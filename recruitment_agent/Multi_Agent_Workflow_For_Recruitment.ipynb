# %% [markdown]
# <a href="https://colab.research.google.com/github/Baldezo313/AI_ML_Agent_RAG_MCP_project_POC/blob/main/recruitment_agent/Multi_Agent_Workflow_For_Recruitment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi Agent Workflow For Recruitment

# %% [markdown]
# ## Introduction

# %% [markdown]
# The Multi Agent Workflow For Recruitment is an automated system designed to help streamline the hiring process through specialized AI agents working in harmony to improve candidate evaluation, save time and resources, and improve overall hiring outcomes.

# %% [markdown]
# ## The Problem

# %% [markdown]
# Today's recruitment landscape faces three critical challenges:
#
# 1. **Overwhelming Volume**: Recruiters struggle to efficiently process large numbers of applications, often missing qualified candidates.
#
# 2. **Manual Inefficiency**: Traditional resume screening is time-consuming, inconsistent, and vulnerable to bias.
#
# 3. **Poor Candidate Experience**: Slow response times and fragmented communication damage employer brand and lose top talent.

# %% [markdown]
# ## Why This Matters
#
# Ineffective recruitment directly impacts business outcomes through:
#
# * **Reduced Performance**: Missing qualified candidates leads to suboptimal hires and team performance
# * **Business Delays**: Extended hiring cycles postpone critical projects and initiatives
# * **Higher Costs**: Inefficient processes and prolonged vacancies increase recruitment costs

# %% [markdown]
# ## Our Solution
# The Multi Agent Workflow For Recruitment addresses these challenges through a coordinated system of specialized AI agents:
#
# 1. **DocumentAgent**: Intelligently extracts and processes text from resumes and job descriptions using advanced Mistral's OCR
#
# 2. **JobAnalysisAgent**: Analyzes job descriptions to identify required skills, experience, and qualifications
#
# 3. **ResumeAnalysisAgent**: Parses resumes to create structured candidate profiles with key capabilities
#
# 4. **MatchingAgent**: Evaluates candidates against job requirements with nuanced understanding beyond keyword matching
#
# 5. **EmailCommunicationAgent**: Generates personalized email communications and schedules interviews with qualified candidates
#
# 6. **CoordinatorAgent**: Orchestrates the entire workflow between agents for seamless operation.
#
# The solution uses Mistral LLM for language understanding, structured output mechanisms for consistent data extraction, and Mistral OCR for document parsing.

# %% [markdown]
# ## Example: Data Scientist Hiring
# To illustrate how the Multi Agent Workflow For Recruitment operates in practice, consider a realistic example:
#
# HireFive needs to hire a Senior Data Scientist with machine learning expertise. The job description specifies requirements including 3+ years of experience, proficiency in Python and deep learning frameworks, and a Master's degree in a quantitative field. From a pool of candidate resumes, the workflow automatically:
#
# * Extracts structured requirements from the job description, identifying critical skills
# * Parses all the resumes, creating standardized profiles with skills, experience, and education
# * Evaluates each candidate, assigning scores like "Technical Skills: 32/40" and "Experience: 25/30"
# * Identifies candidates scoring above the 70-point threshold
# * Automatically sends personalized interview invitations with scheduling links to these candidates
#
# The entire process completes in minutes, providing HireFive's hiring manager with a ranked list of qualified candidates while eliminating hours of manual resume screening.

# %% [markdown]
# ## Solution Architecture
# ![solution_architecture.png](data:image/png;base64,...)

# %% [markdown]
# ### Installation

# %%
# !pip install mistralai
# Out:
# Collecting mistralai
#   Downloading mistralai-2.4.9-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 2.8 MB/s eta 0:00:00
# Collecting eval-type-backport>=0.2.0 (from mistralai)
#   Downloading eval_type_backport-0.4.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from mistralai) (0.28.1)
# Collecting jsonpath-python>=1.0.6 (from mistralai)
#   Downloading jsonpath_python-1.1.6-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.33.1 in /usr/local/lib/python3.12/dist-packages (from mistralai) (1.38.0)
# Collecting opentelemetry-semantic-conventions<0.61,>=0.60b1 (from mistralai)
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pydantic>=2.11.2 in /usr/local/lib/python3.12/dist-packages (from mistralai) (2.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from mistralai) (2.9.0.post0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mistralai) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->mistralai) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->mistralai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->mistralai) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->mistralai) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->mistralai) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<2.0.0,>=1.33.1->mistralai) (8.7.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<2.0.0,>=1.33.1->mistralai) (4.15.0)
# Collecting opentelemetry-api<2.0.0,>=1.33.1 (from mistralai)
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->mistralai) (2.41.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->mistralai) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.33.1->mistralai) (4.1.0)
# Downloading mistralai-2.4.9-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.7 MB/s eta 0:00:00
# Downloading eval_type_backport-0.4.0-py3-none-any.whl (6.4 kB)
# Downloading jsonpath_python-1.1.6-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 15.1 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: jsonpath-python, eval-type-backport, opentelemetry-api, opentelemetry-semantic-conventions, mistralai
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.38.0
#     Uninstalling opentelemetry-api-1.38.0:
#       Successfully uninstalled opentelemetry-api-1.38.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.59b0
#     Uninstalling opentelemetry-semantic-conventions-0.59b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.59b0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-sdk 1.38.0 requires opentelemetry-api==1.38.0, but you have opentelemetry-api 1.39.1 which is incompatible.
# opentelemetry-sdk 1.38.0 requires opentelemetry-semantic-conventions==0.59b0, but you have opentelemetry-semantic-conventions 0.60b1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.39.1 which is incompatible.
# Successfully installed eval-type-backport-0.4.0 jsonpath-python-1.1.6 mistralai-2.4.9 opentelemetry-api-1.39.1 opentelemetry-semantic-conventions-0.60b1

# %% [markdown]
# ### Imports

# %%
import os
import time
import json
import requests
from typing import List, Optional, Dict, Any
from pydantic import BaseModel, Field
from mistralai.client import Mistral

import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# %% [markdown]
# ### Setup API Keys

# %%
os.environ['MISTRAL_API_KEY'] = "" # Get it from https://console.mistral.ai/api-keys

# %% [markdown]
# ### Initialize Mistral API Client

# %%
client = Mistral(api_key=os.environ["MISTRAL_API_KEY"])

# %% [markdown]
# ### Download Data
#
# Here, we download the necessary data for the demonstration.
#
# 1. Job Descrition.
# 2. Candidate Resumes.

# %% [markdown]
# **Helper functions to download Job description and candidate resumes**

# %%
def download_job_description(url, output_path = "job_description.pdf"):
  """
  Download the job description from the given URL and save it to the specified output path.
  """
  response = requests.get(url)
  with open(output_path, "wb") as f:
    f.write(response.content)
  print(f"Downloaded {output_path}")

def download_resumes(url, local_dir="resumes"):
  """
  Download resumes from the given URL.
  """
  response = requests.get(url)

  if response.status_code !=200:
    print("Failled to retrieve folder contents:", response.text)
    return

  data = response.json()
  os.makedirs(local_dir, exist_ok=True)

  print(f"{len(data)} files available for download:")
  for file in data:
    file_name = file["name"]
    download_url = file["download_url"]

    r = requests.get(download_url)
    with open(os.path.join(local_dir, file_name), "wb") as f:
      f.write(r.content)
    print(f"Download {file_name}")

# %% [markdown]
# ### Download Job Description

# %%
url = "https://raw.githubusercontent.com/Baldezo313/AI_ML_Agent_RAG_MCP_project_POC/main/recruitment_agent/job_description.pdf"

output_path = "job_description.pdf"

download_job_description(url, output_path)
# Out:
# Downloaded job_description.pdf

# %% [markdown]
# ### Download Candidate Resumes

# %%
download_resumes(
    url = "https://api.github.com/repos/mistralai/cookbook/contents/mistral/agents/non_framework/recruitment_agent/resumes",
    local_dir="resumes"
)
# Out:
# 13 files available for download:
# Download Resume 10_ Carlos Mendez.pdf
# Download Resume 11_ Alex Patel.pdf
# Download Resume 12_ Taylor Williams.pdf
# Download Resume 13_ Jordan Smith.pdf
# Download Resume 1_ Sarah Chen.pdf
# Download Resume 2_ Michael Rodriguez.pdf
# Download Resume 3_ Jennifer Park.pdf
# Download Resume 4_ David Wilson.pdf
# Download Resume 5_ Priya Sharma.pdf
# Download Resume 6_ James Lee.pdf
# Download Resume 7_ Emily Johnson.pdf
# Download Resume 8_ Robert Thompson.pdf
# Download Resume 9_ Lisa Wang.pdf

# %% [markdown]
# ### Define Pydantic Models
# Pydantic models provide structured data validation between agents, ensuring consistent formats for candidate profiles, job requirements, and evaluation scores while enabling seamless integration with Mistral LLM's parsing capabilities. Following are the different pydantic models we use for
#
# * **Skill**: Represents a candidate's technical or soft skill with its proficiency level and years of experience.
#
# * **Education**: Captures educational qualifications including degree, field of study, institution, and performance metrics.
#
# * **Experience**: Tracks professional experience with role details, duration, utilized skills, and key accomplishments.
#
# * **ContactDetails**: Stores candidate contact information including name, email, and optional communication channels.
#
# * **JobRequirements**: Defines position requirements including mandatory and preferred skills, experience level, and educational qualifications.
#
# * **CandidateProfile**: Consolidates a candidate's complete professional profile including contact details, skills, education, and work history.
#
# * **SkillMatch**: Evaluates individual skill alignment between job requirements and candidate capabilities with confidence scores.
#
# * **CandidateScore**: Provides comprehensive scoring across key evaluation areas with total score calculation and identified strengths/gaps.
#
# * **CandidateResult**: Connects file information with extracted candidate data and evaluation scores for final ranking and selection.

# %% [markdown]
# **Pydantic Models for structured extraction.**

# %%
class Skill(BaseModel):
  name: str = Field(description="Name of the skill or technology")
  level: Optional[str] = Field(description="Proficiency level (beginner, intermediate, advanced)")
  year: Optional[float] = Field(description="Years of experience with this skill")

class Education(BaseModel):
  degree: str = Field(description="Type of degree or certification obtained")
  field: str = Field(description="Field of study or specialization")
  institution: str = Field(description="Name of educational institution")
  year_completed: Optional[int] = Field(description="Year when degree was completed")
  gpa: Optional[float] = Field(description="Grade point Average, typically on 4.0 scale")

class Experience(BaseModel):
    title: str = Field(description="Job title or position held")
    company: str = Field(description="Name of employer or organization")
    duration_years: float = Field(description="Duration of employment in years")
    skills_used: List[str] = Field(description="Skills utilized in this role")
    achievements: List[str] = Field(description="Key accomplishments or responsibilities")
    relevance_score: Optional[float] = Field(description="Relevance to current job opening (0-10 scale)")

class ContactDetails(BaseModel):
  name: str = Field(description="Full name of the candidate")
  email: str = Field(description="Primary email address for contact")
  phone: Optional[str] = Field(description="Phone number with country code if applicable")
  location: Optional[str] = Field(description="Current city and country/state")
  linkedin: Optional[str] = Field(description="LinkedIn profile URL")
  website: Optional[str] = Field(description="Personal or portfolio website URL")

class JobRequirements(BaseModel):
    required_skills: List[Skill] = Field(description="Skills that are mandatory for the position")
    preferred_skills: List[Skill] = Field(description="Skills that are desired but not required")
    min_experience_years: float = Field(description="Minimum years of experience required")
    required_education: List[Education] = Field(description="Mandatory educational qualifications")
    preferred_domains: List[str] = Field(description="Industry domains or sectors preferred for experience")

class CandidateProfile(BaseModel):
    contact_details: ContactDetails = Field(description="Candidate's personal and contact information")
    skills: List[Skill] = Field(description="Technical and soft skills possessed by the candidate")
    education: List[Education] = Field(description="Educational background and qualifications")
    experience: List[Experience] = Field(description="Professional work history and experience")

class SkillMatch(BaseModel):
    skill_name: str = Field(description="Name of the skill being evaluated")
    present: bool = Field(description="Whether the candidate possesses this skill")
    match_level: float = Field(description="How well the candidate's skill matches the requirement (0-10 scale)")
    confidence: float = Field(description="Confidence in the skill evaluation (0-1 scale)")
    notes: str = Field(description="Additional context about the skill match assessment")

class CandidateScore(BaseModel):
    technical_skills_score: float = Field(description="Assessment of technical capabilities (0-40 points)")
    experience_score: float = Field(description="Evaluation of relevant work experience (0-30 points)")
    education_score: float = Field(description="Rating of educational qualifications (0-15 points)")
    additional_score: float = Field(description="Score for other relevant factors (0-15 points)")
    total_score: float = Field(description="Aggregate candidate evaluation score (0-100)")
    key_strengths: List[str] = Field(description="Primary candidate advantages for this role")
    key_gaps: List[str] = Field(description="Areas where the candidate lacks desired qualifications")
    confidence: float = Field(description="Overall confidence in the evaluation accuracy (0-1 scale)")
    notes: str = Field(description="Supplementary observations about the candidate fit")

class CandidateResult(BaseModel):
    file_name: str = Field(description="Name of the source resume file")
    contact_details: ContactDetails = Field(description="Candidate's contact information")
    candidate_profile: CandidateProfile = Field(description="Complete extracted candidate profile")
    score: CandidateScore = Field(description="Detailed evaluation scores and assessment")

# %% [markdown]
# ### Base Agent Class
#
# The `Agent` class serves as the foundation for all specialized agents, providing a standardized interface for processing and communicating between agents in the recruitment workflow.
#
# Each agent implements the common `process()` method while inheriting identity management and communication capabilities.

# %%
class Agent:
  def __init__(self, name: str, client: Mistral):
     self.name = name
     self.client = client

  def process(self, message):
    """Base process method - to be implemented by child classes"""
    raise NotImplementedError("Subclasses must implement process method")

  def communicate(self, recipient_agent, message):
    """Send message to another agent"""
    return recipient_agent.process(message)

# %% [markdown]
# ### DocumentAgent: Handles document extraction and OCR
# The `DocumentAgent` handles document processing by extracting structured text from various files using Mistral's OCR capabilities. It transforms complex resume PDFs and job descriptions into text, serving as the initial data gateway for the entire recruitment workflow.

# %%
class DocumentAgent(Agent):
  def __init__(self, client: Mistral):
    super().__init__("DocumentAgent", client)

  def process(self, file_info):
    """Process document extraction request"""
    file_path, file_name = file_info
    return self.extract_text_from_file(file_path, file_name)

  def extract_text_from_file(self, file_path: str, file_name: str) -> str:
    """Extract text from a file using Mistral OCR"""
    try:
      # Upload the file
      uploaded_file = self.client.files.upload(
          file={
              "file_name": file_name,
              "content": open(file_path, "rb"),
          },
          purpose="ocr"
      )

      # Get signed URL
      signed_url = self.client.files.get_signed_url(file_id=uploaded_file.id)

      # Process with OCR
      ocr_response = self.client.ocr.process(
          model="mistral-ocr-latest",
          document={
              "type": "document_url",
              "document_url": signed_url.url,
          }
      )

      # Extract and return the text
      extracted_text = ""
      for page in ocr_response.pages:
        extracted_text += page.markdown + "\n\n"

      return extracted_text

    except Exception as e:
      print(f"Error extracting text from {file_name}: {str(e)}")
      return ""

# %% [markdown]
# ### JobAnalysisAgent: Handles job requirement extraction and analysis
# The JobAnalysisAgent extracts structured job requirements from plain text job descriptions using Mistral LLM. It transforms unstructured job postings into organized data models capturing required skills, experience levels, and educational qualifications needed for candidate matching.

# %%
class JobAnalysisAgent(Agent):
    def __init__(self, client: Mistral):
        super().__init__("JobAnalysisAgent", client)

    def process(self, jd_text):
        """Process job description text"""
        return self.extract_job_requirements(jd_text)

    def extract_job_requirements(self, jd_text: str) -> JobRequirements:
        """Extract structured job requirements from a job description"""
        prompt = f"""
        Extract the key job requirements from the following job description.
        Focus on required skills, preferred skills, experience requirements, and education requirements.

        Job Description:
        {jd_text}
        """

        response = self.client.chat.parse(
            model="mistral-small-latest",
            messages=[
                {"role": "system", "content": "Extract structured job requirements from the job description."},
                {"role": "user", "content": prompt}
            ],
            response_format=JobRequirements,
            temperature=0
        )

        return json.loads(response.choices[0].message.content)

# %% [markdown]
# ### ResumeAnalysisAgent: Handles resume parsing and profile extraction
# The ResumeAnalysisAgent transforms raw resume text into structured candidate profiles using Mistral LLM's parsing capabilities. It extracts and organizes key information including contact details, skills, education history, and professional experience into standardized data structures for consistent evaluation.

# %%
class ResumeAnalysisAgent(Agent):
    def __init__(self, client: Mistral):
        super().__init__("ResumeAnalysisAgent", client)

    def process(self, resume_text):
        """Process resume text"""
        return self.extract_candidate_profile(resume_text)

    def extract_candidate_profile(self, resume_text: str) -> CandidateProfile:
        """Extract structured candidate information from resume text"""
        prompt = f"""
        Extract the candidate's contact details, skills, education, and experience from the following resume.
        Be thorough and include all relevant information.

        Resume:
        {resume_text}
        """

        response = self.client.chat.parse(
            model="mistral-small-latest",
            messages=[
                {"role": "system", "content": "Extract structured candidate information from the resume."},
                {"role": "user", "content": prompt}
            ],
            response_format=CandidateProfile,
            temperature=0
        )

        return json.loads(response.choices[0].message.content)

# %% [markdown]
# ### MatchingAgent: Evaluates candidate fit against job requirements
# The `MatchingAgent` evaluates candidate profiles against job requirements to generate comprehensive scoring across technical skills, experience, education and additional qualifications. It employs Mistral LLM to assess the quality and relevance of candidate attributes beyond simple keyword matching, producing a detailed evaluation with confidence metrics and identified strengths and gaps.

# %%
class MatchingAgent(Agent):
    def __init__(self, client: Mistral):
        super().__init__("MatchingAgent", client)

    def process(self, data):
        """Process job requirements and candidate profile to generate score"""
        job_requirements, candidate_profile, resume_text = data
        return self.evaluate_candidate(job_requirements, candidate_profile, resume_text)

    def evaluate_candidate(self, job_requirements: JobRequirements, candidate_profile: CandidateProfile, resume_text: str) -> CandidateScore:
        """Evaluate how well a candidate matches the job requirements"""
        # Convert to JSON for inclusion in the prompt
        job_req_json = json.dumps(job_requirements, indent=2)
        candidate_json = json.dumps(candidate_profile, indent=2)

        prompt = f"""
        Evaluate how well the candidate matches the job requirements.

        Job Requirements:
        {job_req_json}

        Candidate Profile:
        {candidate_json}

        Provide a detailed scoring breakdown, highlighting strengths and gaps.
        Assess the quality and relevance of the candidate's experience, not just keyword matches.
        Include confidence levels for your assessment.

        Technical skills should be scored out of 40 points.
        Experience should be scored out of 30 points.
        Education should be scored out of 15 points.
        Additional qualifications should be scored out of 15 points.
        The total score should be out of 100 points.
        """

        response = self.client.chat.parse(
            model="mistral-small-latest",
            messages=[
                {"role": "system", "content": "Evaluate the candidate's match to the job requirements with detailed scoring."},
                {"role": "user", "content": prompt}
            ],
            response_format=CandidateScore,
            temperature=0.2  # Slight randomness for nuanced evaluation
        )

        return json.loads(response.choices[0].message.content)

# %% [markdown]
# ### EmailCommunicationAgent: Handles email generation and sending
#
# The EmailCommunicationAgent generates personalized email communications to candidates and sends them through SMTP integration. It crafts contextually relevant messages based on candidate qualifications and scheduling information, managing the critical final step of candidate engagement in the recruitment workflow.

# %%
class EmailCommunicationAgent(Agent):
    def __init__(self, client: Mistral, sender_email: str, app_password: str):
        super().__init__("EmailCommunicationAgent", client)
        self.sender_email = sender_email
        self.app_password = app_password

    def process(self, data):
        """Process email sending request"""
        candidate, calendly_link, subject = data
        return self.send_interview_invitation(candidate, calendly_link, subject)

    def send_interview_invitation(self, candidate, calendly_link: str, subject: str):
        """Generate and send personalized email to candidate"""
        name = candidate["contact_details"]['name']
        email = candidate["contact_details"]['email']

        # Create email HTML content
        html_content = f"""\
        <html>
          <body>
            <p>Hello {name},</p>
            <p>I'm the Hiring Manager from HireFive. Thank you for applying for the Data Scientist position at our company.</p>
            <p>We were impressed with your background and would like to schedule an initial screening call to discuss your experience and interest in the role.</p>
            <p>Please select a suitable time slot using our <a href="{calendly_link}">Calendly link</a>.</p>
            <p>Looking forward to speaking with you soon.</p>
            <p>Best regards,<br>
            Hiring Manager<br>
            HireFive</p>
          </body>
        </html>
        """

        if self.app_password:
            try:
                self.send_email(email, subject, html_content)
                return f"Email sent to {name} at {email}"
            except Exception as e:
                return f"Failed to send email to {name} ({email}): {str(e)}"
        else:
            return f"Would send email to {name} at {email} - Email subject: {subject}"


    def send_email(self, receiver_email, subject, html_content):
        """Send an email using Gmail SMTP"""
        # Create message container
        message = MIMEMultipart('alternative')
        message['From'] = self.sender_email
        message['To'] = receiver_email
        message['Subject'] = subject

        # Attach HTML part
        message.attach(MIMEText(html_content, 'html'))

        try:
            # Create SMTP session
            server = smtplib.SMTP('smtp.gmail.com', 587)
            server.starttls()  # Enable security

            # Login with Gmail account and app password
            server.login(self.sender_email, self.app_password)

            # Send email
            text = message.as_string()
            server.sendmail(self.sender_email, receiver_email, text)

        finally:
            server.quit()  # Close the connection

# %% [markdown]
# ### CoordinatorAgent: Manages the workflow and coordinates between agents
# The `CoordinatorAgent` orchestrates the entire recruitment workflow by managing communication and data flow between all specialized agents. It initializes the process with job descriptions, distributes resumes, collects evaluation results, applies threshold-based filtering, and triggers candidate communications, serving as the central intelligence that ensures the seamless execution of the multi-agent recruitment system.

# %%
class CoordinatorAgent(Agent):
  def __init__(self, client: Mistral):
    super().__init__("CoordinatorAgent", client)
    self.document_agent = DocumentAgent(client)
    self.job_analysis_agent = JobAnalysisAgent(client)
    self.resume_analysis_agent = ResumeAnalysisAgent(client)
    self.matching_agent = MatchingAgent(client)
    self.email_communication_agent = None   # Will be initialized later with email credentials

  def set_email_communication_agent(self, sender_email: str, app_password: str):
    """Initialize communication agent with email credentials"""
    self.email_communication_agent = EmailCommunicationAgent(self.client, sender_email, app_password)

  def process_hiring_workflow(self, jd_file_path: str, resume_dir: str, output_path: str, threshold_score: float, calendly_link: str, email_subject: str):
    """
    Coordinate the entire hiring workflow from document processing to interview scheduling
    """

    results = []

    # Process job description
    print(f"🤖 DocumentAgent extracting text from job description...")
    jd_text = self.document_agent.process((jd_file_path, os.path.basename(jd_file_path)))

    if not jd_text:
      print("❌ Failed to extract text from job description. Aborting.")
      return results

    # Extract job requirements
    print(f"🤖 JobAnalysisAgent analyzing job description...")
    job_requirements = self.job_analysis_agent.process(jd_text)

    time.sleep(10)

    # Process each resume in the directory
    resume_files = [f for f in os.listdir(resume_dir) if os.path.isfile(os.path.join(resume_dir, f))]

    for filename in resume_files:
      file_path = os.path.join(resume_dir, filename)
      print(f"\n🤖 DocumentAgent processing resume: {filename}")

      # Extract text from resume
      resume_text = self.document_agent.process((file_path, filename))

      time.sleep(10)

      if resume_text:
        # Extract candidate profile
        print(f"🤖 ResumeAnalysisAgent extracting candidate profile...")
        candidate_profile = self.resume_analysis_agent.process(resume_text)

        # Evaluate candidate match
        print(f"🤖 MatchingAgent evaluating candidate {candidate_profile['contact_details']['name']}...")
        score = self.matching_agent.process((job_requirements, candidate_profile, resume_text))

        # Create result object
        result = {
            "file_name": filename,
            "contact_details": candidate_profile["contact_details"],
            "candidate_profile": candidate_profile,
            "score": score
        }
        results.append(result)

        # Add a small delay to avoid rate limits
        time.sleep(10)

      else:
        print(f"❌ DocumentAgent failed to extract text from {filename}. Skipping this resume.")

    # Sort results by total score
    results.sort(key=lambda x: x["score"]["total_score"], reverse=True)

    # Save results to file
    with open(output_path, "w") as f:
      json.dump([result for result in results], f , indent=2)

    print(f"\n🤖 CoordinatorAgent saved results to {output_path}")

    # Print summary of results
    print("\n===== CANDIDATE RANKING =====")
    for i, result in enumerate(results, 1):
      name = result["contact_details"]["name"]
      score = result["score"]["total_score"]
      print(f"{i}. {name} - Score: {score}/100")

    # Send interview invitations to candidates above threshold
    if self.email_communication_agent:
      selected_candidates = [r for r in results if r["score"]["total_score"] >= threshold_score]

      print(f"\n🤖 EmailCommunicationAgent preparing to send interview invitations to {len(selected_candidates)} candidates who scored {threshold_score}+ out of 100...\n")

      for candidate in selected_candidates:
        response = self.email_communication_agent.process((candidate, calendly_link, email_subject))
        time.sleep(1)


    return results

# %% [markdown]
# ## Run the workflow
# To run the Multi Agent Workflow For Recruitment, you simply need to:
#
# * Configure file paths for the job description, resume directory, and output results
# * Set up email credentials and Calendly scheduling link
# * Initialize the CoordinatorAgent with your Mistral client
# * Configure the EmailCommunicationAgent with sender credentials
# * Execute the workflow with your desired threshold score

# %% [markdown]
# ### Define paths

# %%
jd_file_path = "job_description.pdf"
resume_dir = "/content/resumes/"
output_path = "candidate_results.json"

# %% [markdown]
# ### Gmail App Password Setup
# To use the email functionality in the Multi Agent Workflow For Recruitment with Gmail, you'll need to create an app password:
#
# 1. Enable 2-Step Verification on your Google Account:
#
# * Go to your Google Account → Security
# * Under "Signing in to Google," select 2-Step Verification → Get started
#
# 2. Generate an App Password:
#
# * Go to your Google Account → Security
# * Under "Signing in to Google," select App passwords
# * Select "Mail" as the app and "Other" as the device (name it "Recruitment Workflow")
# * Click "Generate"
# * Google will display a 16-character password (four groups of four characters)
#
# 3. Use this app password in your workflow configuration:
#
# - sender_email = "your.email@gmail.com"
# - app_password = "abcd efgh ijkl mnop"  # Your generated app password
#
# This app password bypasses 2FA and allows the workflow to send emails through your Gmail account securely without storing your actual Google password in the code.

# %%
sender_email = ""
app_password = ""
calendly_link = ""
email_subject = "HireFive: Next Steps for Your Data Scientist Application"

# %% [markdown]
# ### Initialize coordinator agent

# %%
coordinator = CoordinatorAgent(client)

# %% [markdown]
# ### Set up communication agent with email credentials

# %%
coordinator.set_email_communication_agent(sender_email, app_password)

# %% [markdown]
# ### Execute hiring workflow
#
# Note: We have considered 5 candidate resumes for simplicity's sake.

# %%
threshold_score = 65    # Only send to candidates with 65+ overall score
results = coordinator.process_hiring_workflow(
    jd_file_path=jd_file_path,
    resume_dir=resume_dir,
    output_path="candidate_results.json",
    threshold_score=threshold_score,
    calendly_link=calendly_link,
    email_subject=email_subject
)
# Out:
# 🤖 DocumentAgent extracting text from job description...
# 🤖 JobAnalysisAgent analyzing job description...
#
# 🤖 DocumentAgent processing resume: Resume 15_ Mamadou Balde.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Mamadou Balde...
#
# 🤖 DocumentAgent processing resume: Resume 3_ Jennifer Park.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Jennifer Park...
#
# 🤖 DocumentAgent processing resume: Resume 4_ David Wilson.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate David Wilson...
#
# 🤖 DocumentAgent processing resume: Resume 14_ Masaidou Ba.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Mamadou Saidou Balde...
#
# 🤖 DocumentAgent processing resume: Resume 13_ Jordan Smith.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Jordan Smith...
#
# 🤖 DocumentAgent processing resume: Resume 11_ Alex Patel.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Alex Patel...
#
# 🤖 DocumentAgent processing resume: Resume 10_ Carlos Mendez.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Carlos Mendez...
#
# 🤖 DocumentAgent processing resume: Resume 12_ Taylor Williams.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Taylor Williams...
#
# 🤖 DocumentAgent processing resume: Resume 6_ James Lee.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate James Lee...
#
# 🤖 DocumentAgent processing resume: Resume 8_ Robert Thompson.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Robert Thompson, PhD...
#
# 🤖 DocumentAgent processing resume: Resume 9_ Lisa Wang.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Lisa Wang...
#
# 🤖 DocumentAgent processing resume: Resume 7_ Emily Johnson.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Emily Johnson...
#
# 🤖 DocumentAgent processing resume: Resume 2_ Michael Rodriguez.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Michael Rodriguez...
#
# 🤖 DocumentAgent processing resume: Resume 5_ Priya Sharma.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Priya Sharma, PhD...
#
# 🤖 DocumentAgent processing resume: Resume 1_ Sarah Chen.pdf
# 🤖 ResumeAnalysisAgent extracting candidate profile...
# 🤖 MatchingAgent evaluating candidate Sarah Chen, PhD...
#
# 🤖 CoordinatorAgent saved results to candidate_results.json
#
# ===== CANDIDATE RANKING =====
# 1. Mamadou Balde - Score: 95/100
# 2. Carlos Mendez - Score: 95/100
# 3. Robert Thompson, PhD - Score: 95/100
# 4. Michael Rodriguez - Score: 95/100
# 5. Sarah Chen, PhD - Score: 95/100
# 6. Mamadou Saidou Balde - Score: 94/100
# 7. Jennifer Park - Score: 93/100
# 8. Lisa Wang - Score: 93/100
# 9. Priya Sharma, PhD - Score: 93/100
# 10. Emily Johnson - Score: 87/100
# 11. David Wilson - Score: 74/100
# 12. James Lee - Score: 54/100
# 13. Jordan Smith - Score: 10/100
# 14. Alex Patel - Score: 7/100
# 15. Taylor Williams - Score: 7/100
#
# 🤖 EmailCommunicationAgent preparing to send interview invitations to 11 candidates who scored 65+ out of 100...

# %% [markdown]
# You can check each of the candidates extracted results.

# %%
results
# Out:
# [{'file_name': 'Resume 15_ Mamadou Balde.pdf',
#   'contact_details': {'name': 'Mamadou Balde',
#    'email': 'baldeba88@gmail.com',
#    'phone': '+33 7 53 26 68 07',
#    'location': 'Paris, France',
#    'linkedin': 'https://www.linkedin.com/in/mamadou-balde',
#    'website': 'https://huggingface.co/mamadou-balde'},
#   'candidate_profile': {'contact_details': {'name': 'Mamadou Balde',
#     'email': 'baldeba88@gmail.com',
#     'phone': '+33 7 53 26 68 07',
#     'location': 'Paris, France',
#     'linkedin': 'https://www.linkedin.com/in/mamadou-balde',
#     'website': 'https://huggingface.co/mamadou-balde'},
#    'skills': [{'name': 'NLP', 'level': 'advanced', 'year': 5},
#     {'name': 'Large Language Models (LLMs)', 'level': 'advanced', 'year': 5},
#     {'name': 'Retrieval-Augmented Generation (RAG)',
#      'level': 'advanced',
#      'year': 4},
#     {'name': 'AI Agents', 'level': 'advanced', 'year': 3},
#     {'name': 'Model Context Protocol (MCP)',
#      'level': 'intermediate',
#      'year': 2},
#     {'name': 'Computer Vision', 'level': 'intermediate', 'year': 3},
#     {'name': 'Fine-tuning', 'level': 'advanced', 'year': 4},
#     {'name': 'Prompt Engineering', 'level': 'advanced', 'year': 4},
#     {'name': 'LangChain', 'level': 'advanced', 'year': 3},
#     {'name': 'PyTorch', 'level': 'advanced', 'year': 5},
#     {'name': 'TensorFlow', 'level': 'advanced', 'year': 4},
#     {'name': 'Scikit-learn', 'level': 'advanced', 'year': 5},
#     {'name': 'Transformers (BERT, GPT, Mistral)',
#      'level': 'advanced',
#      'year': 5},
#     {'name': 'Hugging Face', 'level': 'advanced', 'year': 5},
#     {'name': 'FAISS', 'level': 'advanced', 'year': 3},
#     {'name': 'Python', 'level': 'advanced', 'year': 7},
#     {'name': 'SQL', 'level': 'advanced', 'year': 5},
#     {'name': 'PySpark', 'level': 'advanced', 'year': 4},
#     {'name': 'Scala', 'level': 'intermediate', 'year': 3},
#     {'name': 'R', 'level': 'intermediate', 'year': 4},
#     {'name': 'SAS', 'level': 'intermediate', 'year': 2},
#     {'name': 'C', 'level': 'basic', 'year': 2},
#     {'name': 'Power BI', 'level': 'advanced', 'year': 4},
#     {'name': 'Tableau', 'level': 'intermediate', 'year': 2},
#     {'name': 'Looker Studio', 'level': 'intermediate', 'year': 2},
#     {'name': 'PostgreSQL', 'level': 'advanced', 'year': 5},
#     {'name': 'MySQL', 'level': 'advanced', 'year': 5},
#     {'name': 'MongoDB', 'level': 'intermediate', 'year': 3},
#     {'name': 'Neo4j', 'level': 'intermediate', 'year': 2},
#     {'name': 'MSSQL (SSAS/SSIS/SSRS)', 'level': 'intermediate', 'year': 3},
#     {'name': 'Apache Spark', 'level': 'advanced', 'year': 5},
#     {'name': 'Hadoop', 'level': 'intermediate', 'year': 3},
#     {'name': 'HDFS', 'level': 'intermediate', 'year': 3},
#     {'name': 'Databricks', 'level': 'advanced', 'year': 4},
#     {'name': 'AWS (SageMaker, EC2, S3, Lambda, ECS)',
#      'level': 'advanced',
#      'year': 4},
#     {'name': 'Azure ML', 'level': 'intermediate', 'year': 2},
#     {'name': 'GCP (BigQuery, Vertex AI)', 'level': 'intermediate', 'year': 2},
#     {'name': 'Docker', 'level': 'advanced', 'year': 5},
#     {'name': 'Kubernetes', 'level': 'intermediate', 'year': 3},
#     {'name': 'MLflow', 'level': 'advanced', 'year': 4},
#     {'name': 'Jenkins', 'level': 'intermediate', 'year': 3},
#     {'name': 'Git/GitHub', 'level': 'advanced', 'year': 6},
#     {'name': 'Gerrit', 'level': 'intermediate', 'year': 3},
#     {'name': 'Agile (Scrum)', 'level': 'advanced', 'year': 5},
#     {'name': 'Jira', 'level': 'advanced', 'year': 5},
#     {'name': 'Confluence', 'level': 'advanced', 'year': 5}],
#    'education': [{'degree': "Master's Degree",
#      'field': 'Data Science & Artificial Intelligence',
#      'institution': 'Data ScienceTech Institute (DSTI)',
#      'year_completed': 2023,
#      'gpa': None},
#     {'degree': "Master's Degree",
#      'field': 'Applied Mathematics & Statistics',
#      'institution': 'Université Clermont Auvergne',
#      'year_completed': 2021,
#      'gpa': None},
#     {'degree': "Bachelor's Degree",
#      'field': 'Mathematics',
#      'institution': 'Aix-Marseille Université',
#      'year_completed': 2019,
#      'gpa': None}],
#    'experience': [{'title': 'AI Engineer | Data Scientist',
#      'company': 'Nokia Corporation',
#      'duration_years': 3.58,
#      'skills_used': ['NLP',
#       'LLMs',
#       'RAG',
#       'AI Agents',
#       'MLOps',
#       'CI/CD',
#       'Python',
#       'SQL',
#       'Spark',
#       'Power BI',
#       'ETL Pipelines',
#       'Agile (Scrum)',
#       'Jira',
#       'Confluence'],
#      'achievements': ['Extracted and processed large volumes of complex data from diverse sources to monitor and improve software build stability in CI/CD pipelines for 5G L2/L3 network deployments',
#       'Developed custom KPI metrics to evaluate system performance (compilation time, success rates, pipeline stability) for global Agile teams',
#       'Built Machine Learning models to predict build failures, reduce errors, and anticipate pipeline outages in a high-stakes industrial environment',
#       'Designed interactive Power BI dashboards to track key operational indicators (build time, success rate) for stakeholders, enabling data-driven decision-making',
#       'Implemented robust ETL pipelines to automate real-time data extraction, transformation, and loading using Python, SQL, Spark, and PowerBI',
#       'Led the design and deployment of an automated system tracking code evolution (lines added, removed, modified) across repositories, improving codebase transparency and maintenance'],
#      'relevance_score': 10},
#     {'title': 'Data Scientist | Analyst',
#      'company': 'Michelin',
#      'duration_years': 0.33,
#      'skills_used': ['Python',
#       'SQL',
#       'Machine Learning',
#       'Feature Engineering',
#       'Data Analysis',
#       'R',
#       'SAS'],
#      'achievements': ['Analysed a dataset of 2.7M observations (28 variables, 40 vehicles) from embedded telematics data to optimise vehicle recognition',
#       'Performed feature engineering to extract behavioural indicators (aggressiveness, stability, longitudinal/lateral variations) from sensor data',
#       'Developed Machine Learning models to optimise vehicle recognition accuracy, leveraging driving behaviour patterns',
#       'Identified behavioural patterns linked to weather conditions and trip schedules, providing actionable insights for R&D'],
#      'relevance_score': 8},
#     {'title': 'Data Scientist | Analyst',
#      'company': 'Blaise Pascal Mathematics Laboratory',
#      'duration_years': 0.33,
#      'skills_used': ['Python',
#       'R',
#       'Statistical Modelling',
#       'Data Visualisation',
#       'SQL',
#       'SAS'],
#      'achievements': ['Conducted exploratory analysis and statistical modelling across 96 French departments to study socio-economic determinants of crime rates',
#       'Studied rates of crimes against persons, burglaries, and car thefts in relation to socio-economic variables (unemployment, poverty, urbanisation, single-parent households)',
#       'Identified significant correlations between crime levels, economic precarity, and urban density using multivariate analysis',
#       'Produced analytical reports and visualisations for laboratory researchers and partner authorities, supporting evidence-based policy recommendations'],
#      'relevance_score': 7},
#     {'title': 'Freelance AI Engineer - Clinical-Safe Medical AI Chatbot',
#      'company': 'Self-Employed',
#      'duration_years': 0.5,
#      'skills_used': ['NLP',
#       'LLMs',
#       'RAG',
#       'LangChain',
#       'Transformers',
#       'FAISS',
#       'Python',
#       'Hugging Face',
#       'Gradio',
#       'RAGAS',
#       'CI/CD'],
#      'achievements': ['Designed and deployed an end-to-end RAG system for a medical PhD student to securely query confidential research documents without external data leakage',
#       'Architected a full RAG pipeline: PDF ingestion → chunking → embeddings (BAAI/bge-small-en) → FAISS vector store → semantic retrieval → LLM generation with custom clinical-safe prompt to enforce strict grounding',
#       'Integrated Qwen2.5-0.5B-Instruct via HuggingFacePipeline with a fallback mechanism for out-of-scope questions to prevent hallucinations',
#       'Implemented a RAGAS evaluation pipeline (faithfulness, answer relevancy, context relevancy) to measure RAG quality and iterated on design based on results',
#       'Deployed the system on Hugging Face Spaces with a Gradio UI, optimised for constrained CPU environments (thread management, float32 fallback, cache redirection)'],
#      'relevance_score': 9}]},
#   'score': {'technical_skills_score': 38,
#    'experience_score': 28,
#    'education_score': 15,
#    'additional_score': 14,
#    'total_score': 95,
#    'key_strengths': ['Exceptional proficiency in Python (7 years) and advanced expertise in core ML libraries (scikit-learn, PyTorch, TensorFlow, Hugging Face, Transformers) with direct application in NLP and LLM projects',
#     'Strong foundation in statistical modeling and machine learning algorithms, demonstrated through academic research and industrial applications (e.g., crime rate modeling, vehicle recognition optimization)',
#     'Advanced SQL skills (5 years) with experience in PostgreSQL, MySQL, and Spark SQL, supporting robust data pipeline development',
#     'Extensive experience with cloud platforms (AWS advanced, Azure/GCP intermediate) and MLOps tools (MLflow, Docker, Kubernetes, CI/CD pipelines)',
#     'Proven expertise in NLP, RAG systems, and AI agents, with hands-on deployment of production-grade systems (e.g., clinical-safe medical chatbot using RAGAS evaluation)',
#     'Demonstrated ability to bridge technical and business needs through interactive dashboards (Power BI advanced) and stakeholder communication',
#     'Strong collaboration skills evidenced by Agile/Scrum experience (5 years) and leadership in cross-functional teams'],
#    'key_gaps': ['Lacks direct experience with NumPy and Pandas at an advanced level (though Python proficiency suggests quick adaptability)',
#     'Limited exposure to traditional statistical modeling techniques (e.g., regression, time series) outside of academic projects',
#     "No explicit mention of experience with scikit-learn's advanced features (e.g., ensemble methods, hyperparameter tuning) in industrial settings",
#     'Gaps in preferred cloud certifications (AWS/Azure/GCP) despite practical experience',
#     'Minimal mention of collaboration with healthcare/finance domains (preferred domains), though clinical-safe AI project shows healthcare relevance'],
#    'confidence': 0.95,
#    'notes': 'The candidate is an exceptionally strong match for roles requiring advanced ML/NLP expertise, particularly in AI agent, RAG, and LLM applications. While their profile leans heavily toward modern AI techniques (e.g., Transformers, RAG) rather than traditional data science stacks (NumPy/Pandas), their Python proficiency and project experience suggest rapid upskilling. The lack of explicit scikit-learn/Pandas experience in job descriptions is mitigated by their broader Python and ML ecosystem expertise. Their academic background in applied mathematics and data science is highly relevant, and their industrial experience at Nokia and Michelin demonstrates practical impact. The clinical-safe AI project is a standout example of applying advanced techniques to real-world constraints. Confidence is high due to the alignment of skills, experience, and outcomes with the job requirements, though minor gaps in traditional tooling could be addressed with targeted training.'}},
#  {'file_name': 'Resume 10_ Carlos Mendez.pdf',
#   'contact_details': {'name': 'Carlos Mendez',
#    'email': 'c.mendez@email.com',
#    'phone': '+1 (415) 555-6789',
#    'location': 'San Francisco, CA',
#    'linkedin': 'https://linkedin.com/in/carlosmendez',
#    'website': None},
#   'candidate_profile': {'contact_details': {'name': 'Carlos Mendez',
#     'email': 'c.mendez@email.com',
#     'phone': '+1 (415) 555-6789',
#     'location': 'San Francisco, CA',
#     'linkedin': 'https://linkedin.com/in/carlosmendez',
#     'website': None},
#    'skills': [{'name': 'Python', 'level': 'Advanced', 'year': 4},
#     {'name': 'R', 'level': 'Advanced', 'year': 4},
#     {'name': 'SQL', 'level': 'Intermediate', 'year': 3},
#     {'name': 'Pandas', 'level': 'Advanced', 'year': 4},
#     {'name': 'NumPy', 'level': 'Advanced', 'year': 4},
#     {'name': 'scikit-learn', 'level': 'Advanced', 'year': 4},
#     {'name': 'TensorFlow', 'level': 'Advanced', 'year': 3},
#     {'name': 'ggplot2', 'level': 'Advanced', 'year': 4},
#     {'name': 'caret', 'level': 'Advanced', 'year': 3},
#     {'name': 'Predictive Modeling', 'level': 'Advanced', 'year': 4},
#     {'name': 'Regression', 'level': 'Advanced', 'year': 4},
#     {'name': 'Classification', 'level': 'Advanced', 'year': 4},
#     {'name': 'Survival Analysis', 'level': 'Advanced', 'year': 3},
#     {'name': 'Hypothesis Testing', 'level': 'Advanced', 'year': 4},
#     {'name': 'Experimental Design', 'level': 'Advanced', 'year': 3},
#     {'name': 'Bayesian Analysis', 'level': 'Intermediate', 'year': 2},
#     {'name': 'FHIR', 'level': 'Intermediate', 'year': 2},
#     {'name': 'HL7', 'level': 'Intermediate', 'year': 2},
#     {'name': 'ICD-10 coding', 'level': 'Intermediate', 'year': 2},
#     {'name': 'Epic', 'level': 'Basic', 'year': 1},
#     {'name': 'Tableau', 'level': 'Advanced', 'year': 3},
#     {'name': 'R Shiny', 'level': 'Advanced', 'year': 3},
#     {'name': 'Matplotlib', 'level': 'Advanced', 'year': 4},
#     {'name': 'Seaborn', 'level': 'Advanced', 'year': 3},
#     {'name': 'Git', 'level': 'Advanced', 'year': 4},
#     {'name': 'Jupyter', 'level': 'Advanced', 'year': 4},
#     {'name': 'RStudio', 'level': 'Advanced', 'year': 4},
#     {'name': 'Docker', 'level': 'Intermediate', 'year': 2}],
#    'education': [{'degree': 'MS in Health Data Science',
#      'field': 'Health Data Science',
#      'institution': 'University of California, San Francisco',
#      'year_completed': 2018,
#      'gpa': 3.8},
#     {'degree': 'BS in Statistics',
#      'field': 'Statistics',
#      'institution': 'University of California, Los Angeles',
#      'year_completed': 2016,
#      'gpa': 3.7}],
#    'experience': [{'title': 'Data Scientist',
#      'company': 'HealthTech Innovations',
#      'duration_years': 3.1,
#      'skills_used': ['Python',
#       'R',
#       'SQL',
#       'Pandas',
#       'NumPy',
#       'scikit-learn',
#       'TensorFlow',
#       'Predictive Modeling',
#       'Regression',
#       'Classification',
#       'Survival Analysis',
#       'Hypothesis Testing',
#       'Experimental Design',
#       'FHIR',
#       'HL7',
#       'ICD-10 coding',
#       'Tableau',
#       'R Shiny',
#       'Matplotlib',
#       'Seaborn',
#       'Git',
#       'Jupyter',
#       'RStudio',
#       'Docker'],
#      'achievements': ['Developed predictive models for hospital readmission risk, reducing 30-day readmissions by 15%',
#       'Created patient segmentation models to identify high-risk populations for targeted interventions',
#       'Built machine learning pipelines for processing electronic health record data',
#       'Collaborated with clinical staff to translate business needs into analytical frameworks',
#       'Presented findings and recommendations to executive leadership and clinical teams',
#       'Ensured compliance with HIPAA and other healthcare data regulations'],
#      'relevance_score': 10},
#     {'title': 'Healthcare Analyst',
#      'company': 'San Francisco General Hospital',
#      'duration_years': 2.1,
#      'skills_used': ['R',
#       'SQL',
#       'Pandas',
#       'ggplot2',
#       'caret',
#       'Predictive Modeling',
#       'Regression',
#       'Classification',
#       'Hypothesis Testing',
#       'Experimental Design',
#       'FHIR',
#       'HL7',
#       'ICD-10 coding',
#       'Tableau',
#       'R Shiny',
#       'Matplotlib',
#       'Seaborn',
#       'Git',
#       'Jupyter',
#       'RStudio'],
#      'achievements': ['Conducted statistical analysis of patient flow data to optimize emergency department operations',
#       'Built dashboards to monitor key performance indicators for hospital administration',
#       'Developed models to predict patient length of stay with 82% accuracy',
#       'Performed analysis of clinical quality measures for regulatory reporting',
#       'Collaborated with physicians and nurses to implement data-driven improvements'],
#      'relevance_score': 9}]},
#   'score': {'technical_skills_score': 38,
#    'experience_score': 28,
#    'education_score': 15,
#    'additional_score': 14,
#    'total_score': 95,
#    'key_strengths': ['Advanced proficiency in all required technical skills (Python, NumPy, Pandas, scikit-learn, SQL, machine learning algorithms, statistical modeling) with 3-4 years of experience',
#     'Strong background in healthcare data science, including FHIR, HL7, ICD-10 coding, and Epic (though Epic is basic)',
#     'Demonstrated ability to develop predictive models with real-world impact (e.g., reducing hospital readmissions by 15%)',
#     'Excellent communication and collaboration skills, as evidenced by presentations to executive leadership and clinical teams',
#     'Advanced experience with visualization tools (Tableau, R Shiny, Matplotlib, Seaborn) and version control (Git)',
#     'Relevant education: MS in Health Data Science and BS in Statistics from top institutions with strong GPAs',
#     'Experience in regulated environments (HIPAA compliance) and healthcare domains (HealthTech Innovations, San Francisco General Hospital)',
#     'Proficient in both Python and R ecosystems, with advanced skills in predictive modeling and statistical techniques'],
#    'key_gaps': ['Lacks advanced experience with PyTorch (only TensorFlow is advanced), AWS, Azure, GCP, Spark, Hadoop, and PowerBI (though Tableau is advanced)',
#     'Limited experience with cloud platforms (only intermediate Docker, no mention of cloud services)',
#     'No explicit mention of PowerBI (though Tableau is advanced)',
#     'Basic experience with Epic (EHR system), which may not meet advanced requirements',
#     'Bayesian Analysis is only intermediate (2 years), not advanced',
#     'No experience with Hadoop or Spark, which are preferred skills'],
#    'confidence': 0.95,
#    'notes': "Carlos Mendez is an exceptionally strong candidate for this role, with near-perfect alignment to the required technical skills and healthcare domain expertise. His advanced skills in Python, machine learning, and statistical modeling are complemented by his healthcare-specific knowledge (FHIR, HL7, ICD-10). The candidate's real-world impact in predictive modeling (e.g., reducing readmissions) and collaboration with clinical teams demonstrates both technical and soft skills. The primary gaps are in cloud platforms (AWS/Azure/GCP) and some preferred tools (PyTorch, Spark, Hadoop), but these are not deal-breakers given his strong foundation. The candidate's education (MS in Health Data Science) is highly relevant and exceeds the minimum requirement. Overall, this is a top-tier candidate with minimal weaknesses."}},
#  {'file_name': 'Resume 8_ Robert Thompson.pdf',
#   'contact_details': {'name': 'Robert Thompson, PhD',
#    'email': 'r.thompson@email.com',
#    'phone': '(925) 555-8976',
#    'location': 'Walnut Creek, CA',
#    'linkedin': 'https://linkedin.com/in/robertthompson',
#    'website': None},
#   'candidate_profile': {'contact_details': {'name': 'Robert Thompson, PhD',
#     'email': 'r.thompson@email.com',
#     'phone': '(925) 555-8976',
#     'location': 'Walnut Creek, CA',
#     'linkedin': 'https://linkedin.com/in/robertthompson',
#     'website': None},
#    'skills': [{'name': 'Python', 'level': 'Advanced', 'year': 8},
#     {'name': 'MATLAB', 'level': 'Advanced', 'year': 8},
#     {'name': 'C++', 'level': 'Intermediate', 'year': 5},
#     {'name': 'SQL', 'level': 'Intermediate', 'year': 5},
#     {'name': 'NumPy', 'level': 'Advanced', 'year': 8},
#     {'name': 'Pandas', 'level': 'Advanced', 'year': 8},
#     {'name': 'scikit-learn', 'level': 'Advanced', 'year': 8},
#     {'name': 'TensorFlow', 'level': 'Advanced', 'year': 6},
#     {'name': 'PyTorch', 'level': 'Advanced', 'year': 6},
#     {'name': 'Time Series Forecasting', 'level': 'Advanced', 'year': 8},
#     {'name': 'Bayesian Methods', 'level': 'Advanced', 'year': 8},
#     {'name': 'Monte Carlo Simulations', 'level': 'Advanced', 'year': 8},
#     {'name': 'Spark', 'level': 'Intermediate', 'year': 3},
#     {'name': 'Hadoop', 'level': 'Basic', 'year': 2},
#     {'name': 'Matplotlib', 'level': 'Advanced', 'year': 8},
#     {'name': 'Seaborn', 'level': 'Advanced', 'year': 8},
#     {'name': 'Plotly', 'level': 'Advanced', 'year': 6},
#     {'name': 'Tableau', 'level': 'Intermediate', 'year': 4},
#     {'name': 'Git', 'level': 'Advanced', 'year': 8},
#     {'name': 'Linux', 'level': 'Advanced', 'year': 8},
#     {'name': 'HPC systems', 'level': 'Advanced', 'year': 8}],
#    'education': [{'degree': 'PhD in Physics',
#      'field': 'Physics',
#      'institution': 'Stanford University',
#      'year_completed': 2013,
#      'gpa': None},
#     {'degree': 'MS in Physics',
#      'field': 'Physics',
#      'institution': 'Massachusetts Institute of Technology',
#      'year_completed': 2009,
#      'gpa': 3.95},
#     {'degree': 'BS in Physics and Mathematics (Double Major)',
#      'field': 'Physics and Mathematics',
#      'institution': 'California Institute of Technology',
#      'year_completed': 2007,
#      'gpa': 3.9}],
#    'experience': [{'title': 'Lead Data Scientist',
#      'company': 'EnergyGrid Solutions',
#      'duration_years': 5.25,
#      'skills_used': ['Python',
#       'MATLAB',
#       'NumPy',
#       'Pandas',
#       'scikit-learn',
#       'TensorFlow',
#       'PyTorch',
#       'Time Series Forecasting',
#       'Bayesian Methods',
#       'Monte Carlo Simulations',
#       'Git',
#       'Linux',
#       'HPC systems',
#       'Leadership',
#       'Team Management',
#       'Stakeholder Communication'],
#      'achievements': ['Led a team of 5 data scientists developing predictive models for energy consumption and grid optimization',
#       'Created time series forecasting models for electricity demand prediction with 92% accuracy',
#       'Developed anomaly detection algorithms to identify potential equipment failures, reducing downtime by 35%',
#       'Built optimization algorithms for renewable energy integration, improving efficiency by 18%',
#       'Collaborated with engineering teams to implement models into production systems',
#       'Presented findings to executive leadership and external stakeholders'],
#      'relevance_score': 10},
#     {'title': 'Data Scientist',
#      'company': 'National Energy Research Laboratory',
#      'duration_years': 5.75,
#      'skills_used': ['Python',
#       'MATLAB',
#       'NumPy',
#       'Pandas',
#       'scikit-learn',
#       'TensorFlow',
#       'PyTorch',
#       'Time Series Forecasting',
#       'Bayesian Methods',
#       'Monte Carlo Simulations',
#       'Git',
#       'Linux',
#       'HPC systems',
#       'Research',
#       'Publications',
#       'Interdisciplinary Collaboration'],
#      'achievements': ['Designed and implemented machine learning models for energy systems optimization',
#       'Conducted research on applying reinforcement learning to grid management problems',
#       'Developed physics-informed neural networks for complex system modeling',
#       'Published 7 papers in peer-reviewed journals on energy forecasting and optimization',
#       'Collaborated with interdisciplinary teams of physicists, engineers, and computer scientists'],
#      'relevance_score': 9},
#     {'title': 'Postdoctoral Researcher',
#      'company': 'University of California, Berkeley - Physics Department',
#      'duration_years': 1.75,
#      'skills_used': ['Python',
#       'MATLAB',
#       'C++',
#       'NumPy',
#       'Pandas',
#       'scikit-learn',
#       'Git',
#       'Linux',
#       'HPC systems',
#       'Research',
#       'Mentoring',
#       'Publications'],
#      'achievements': ['Conducted research on computational physics and complex systems modeling',
#       'Developed simulation algorithms for quantum systems using high-performance computing',
#       'Mentored graduate students on computational methods and data analysis',
#       'Published 3 papers in high-impact physics journals'],
#      'relevance_score': 8}]},
#   'score': {'technical_skills_score': 38,
#    'experience_score': 28,
#    'education_score': 15,
#    'additional_score': 14,
#    'total_score': 95,
#    'key_strengths': ['Exceptional proficiency in all required technical skills (Python, NumPy, Pandas, scikit-learn, SQL, machine learning algorithms, statistical modeling) at an advanced level with 8+ years of experience',
#     'Strong background in preferred skills like TensorFlow, PyTorch, Spark, and Git, with advanced expertise in TensorFlow/PyTorch and intermediate in others',
#     'Extensive experience with data visualization tools (Matplotlib, Seaborn, Plotly) and HPC systems',
#     'PhD in Physics from Stanford University, demonstrating deep quantitative and analytical capabilities',
#     'Over 12 years of relevant industry and research experience in energy systems, forecasting, and optimization',
#     'Proven track record of leading teams, publishing research, and implementing models in production environments',
#     'Strong problem-solving and communication skills as evidenced by leadership roles and stakeholder presentations',
#     'Demonstrated ability to work in interdisciplinary teams and apply advanced statistical/machine learning techniques to real-world problems'],
#    'key_gaps': ['SQL proficiency is listed as intermediate (5 years) rather than advanced, which is a required skill',
#     'Lacks explicit experience with cloud platforms (AWS, Azure, GCP) despite having intermediate-level skills in other tools',
#     'No direct experience mentioned in preferred domains (Healthcare, Finance, AI-powered analytics), though energy systems are closely related to analytics',
#     'Hadoop experience is basic (2 years), which may not meet intermediate preference',
#     'No mention of PowerBI, which is a preferred skill',
#     'Experience in energy sector may not directly translate to other preferred domains'],
#    'confidence': 0.95,
#    'notes': 'The candidate is an exceptionally strong fit for the technical and quantitative aspects of the role, with deep expertise in core machine learning and statistical modeling tools. Their PhD and extensive research/industry experience in energy systems demonstrate a high level of analytical rigor. While they meet or exceed all required skills and most preferred skills, minor gaps exist in SQL proficiency (intermediate vs. advanced) and cloud platforms. The lack of direct experience in healthcare/finance is mitigated by their strong quantitative foundation and adaptability. Their leadership experience and publication record further strengthen their candidacy. The only notable weakness is the absence of PowerBI experience, which could be easily addressed through training.'}},
#  {'file_name': 'Resume 2_ Michael Rodriguez.pdf',
#   'contact_details': {'name': 'Michael Rodriguez',
#    'email': 'michael.rodriguez@email.com',
#    'phone': '+15105557321',
#    'location': 'Oakland, CA',
#    'linkedin': 'https://linkedin.com/in/michaelrodriguez',
#    'website': None},
#   'candidate_profile': {'contact_details': {'name': 'Michael Rodriguez',
#     'email': 'michael.rodriguez@email.com',
#     'phone': '+15105557321',
#     'location': 'Oakland, CA',
#     'linkedin': 'https://linkedin.com/in/michaelrodriguez',
#     'website': None},
#    'skills': [{'name': 'Python', 'level': 'Advanced', 'year': 4},
#     {'name': 'SQL', 'level': 'Advanced', 'year': 4},
#     {'name': 'R', 'level': 'Intermediate', 'year': 2},
#     {'name': 'NumPy', 'level': 'Advanced', 'year': 4},
#     {'name': 'Pandas', 'level': 'Advanced', 'year': 4},
#     {'name': 'scikit-learn', 'level': 'Advanced', 'year': 4},
#     {'name': 'XGBoost', 'level': 'Advanced', 'year': 3},
#     {'name': 'TensorFlow', 'level': 'Advanced', 'year': 3},
#     {'name': 'AWS (EC2, S3, Redshift)', 'level': 'Advanced', 'year': 3},
#     {'name': 'Spark', 'level': 'Intermediate', 'year': 2},
#     {'name': 'Tableau', 'level': 'Advanced', 'year': 4},
#     {'name': 'Matplotlib', 'level': 'Advanced', 'year': 4},
#     {'name': 'Seaborn', 'level': 'Advanced', 'year': 3},
#     {'name': 'PostgreSQL', 'level': 'Advanced', 'year': 4},
#     {'name': 'MySQL', 'level': 'Advanced', 'year': 3},
#     {'name': 'Git', 'level': 'Advanced', 'year': 4},
#     {'name': 'Jupyter', 'level': 'Advanced', 'year': 4},
#     {'name': 'Docker', 'level': 'Intermediate', 'year': 2}],
#    'education': [{'degree': 'MS in Statistics',
#      'field': 'Statistics',
#      'institution': 'University of California, Berkeley',
#      'year_completed': 2018,
#      'gpa': 3.8},
#     {'degree': 'BS in Mathematics',
#      'field': 'Mathematics',
#      'institution': 'University of California, Los Angeles',
#      'year_completed': 2016,
#      'gpa': 3.7}],
#    'experience': [{'title': 'Data Scientist',
#      'company': 'Fintech Solutions Inc.',
#      'duration_years': 4,
#      'skills_used': ['Machine Learning',
#       'Predictive Modeling',
#       'A/B Testing',
#       'Statistical Analysis',
#       'Fraud Detection',
#       'Customer Segmentation',
#       'Churn Prediction',
#       'Tableau',
#       'Python',
#       'SQL',
#       'XGBoost',
#       'TensorFlow',
#       'AWS',
#       'Git',
#       'Jupyter',
#       'Docker'],
#      'achievements': ['Built and deployed machine learning models for fraud detection, reducing false positives by 30% while maintaining 99% fraud capture rate',
#       'Designed and implemented a customer segmentation model using clustering algorithms, leading to a 15% increase in marketing campaign conversion rates',
#       'Developed a churn prediction model with 85% accuracy, enabling proactive retention strategies',
#       'Created interactive dashboards for executive reporting using Tableau',
#       'Mentored junior data scientists and analytics interns',
#       'Collaborated with engineering team to optimize model deployment processes'],
#      'relevance_score': 10},
#     {'title': 'Data Analyst',
#      'company': 'Retail Analytics Group',
#      'duration_years': 2,
#      'skills_used': ['A/B Testing',
#       'Predictive Modeling',
#       'Time Series Forecasting',
#       'ETL Pipelines',
#       'Automated Reporting',
#       'Customer Lifetime Value Modeling',
#       'Python',
#       'SQL',
#       'PostgreSQL',
#       'MySQL'],
#      'achievements': ['Conducted A/B testing for website optimizations, resulting in a 12% increase in conversion rate',
#       'Built predictive models for inventory management using time series forecasting',
#       'Created ETL pipelines for data cleaning and preprocessing using Python and SQL',
#       'Implemented automated reporting solutions, saving 15+ hours of manual work weekly',
#       'Collaborated with marketing teams to develop customer lifetime value models'],
#      'relevance_score': 8}]},
#   'score': {'technical_skills_score': 38,
#    'experience_score': 28,
#    'education_score': 15,
#    'additional_score': 14,
#    'total_score': 95,
#    'key_strengths': ['Advanced proficiency in all required technical skills (Python, NumPy, Pandas, scikit-learn, SQL, machine learning algorithms, statistical modeling) with 3-4 years of experience',
#     'Strong background in machine learning and statistical modeling with demonstrated impact (e.g., fraud detection, churn prediction, customer segmentation)',
#     'Extensive experience with cloud platforms (AWS) and big data tools (Spark), exceeding preferred skill requirements',
#     'Advanced skills in data visualization (Tableau) and visualization libraries (Matplotlib, Seaborn)',
#     'Relevant work experience in fintech and retail analytics, directly aligning with preferred domains (Finance, AI-powered analytics)',
#     'Strong educational foundation with an MS in Statistics from UC Berkeley (GPA 3.8) and BS in Mathematics (GPA 3.7)',
#     'Proven problem-solving and communication skills through achievements like mentoring junior team members and creating executive dashboards',
#     'Experience with modern data science workflows (Docker, Git, Jupyter) and deployment processes'],
#    'key_gaps': ['Lacks explicit experience with PyTorch (only TensorFlow mentioned), though TensorFlow is at advanced level',
#     'No mention of Azure or GCP, despite AWS being at advanced level',
#     'Limited experience with Hadoop (only Spark mentioned at intermediate level)',
#     'No direct experience in Healthcare domain, though Finance and AI-powered analytics are well-covered',
#     'Docker and Spark skills are intermediate (2 years), slightly below preferred intermediate level for some tools'],
#    'confidence': 0.95,
#    'notes': 'Michael Rodriguez is an exceptionally strong candidate for this role, with advanced technical skills in all required areas and significant relevant experience. His background in fintech and retail analytics directly aligns with the preferred domains (Finance, AI-powered analytics). While he meets all required skills at an advanced level, he falls slightly short in a few preferred skills (PyTorch, Azure/GCP, Hadoop) and domains (Healthcare). However, his TensorFlow and AWS expertise, along with his strong educational background and proven impact in previous roles, make him a standout candidate. The confidence in this evaluation is high due to the clear alignment between his skills, experience, and the job requirements.'}},
#  {'file_name': 'Resume 1_ Sarah Chen.pdf',
#   'contact_details': {'name': 'Sarah Chen, PhD',
#    'email': 'san.francisco.ca@gmail.com',
#    'phone': '+1 (415) 555-9876',
#    'location': 'San Francisco, CA',
#    'linkedin': 'https://linkedin.com/in/sarahchen',
#    'website': None},
#   'candidate_profile': {'contact_details': {'name': 'Sarah Chen, PhD',
#     'email': 'san.francisco.ca@gmail.com',
#     'phone': '+1 (415) 555-9876',
#     'location': 'San Francisco, CA',
#     'linkedin': 'https://linkedin.com/in/sarahchen',
#     'website': None},
#    'skills': [{'name': 'Python', 'level': 'Advanced', 'year': 7},
#     {'name': 'R', 'level': 'Intermediate', 'year': 5},
#     {'name': 'SQL', 'level': 'Advanced', 'year': 6},
#     {'name': 'Java', 'level': 'Basic', 'year': 2},
#     {'name': 'NumPy', 'level': 'Advanced', 'year': 6},
#     {'name': 'Pandas', 'level': 'Advanced', 'year': 6},
#     {'name': 'scikit-learn', 'level': 'Advanced', 'year': 6},
#     {'name': 'TensorFlow', 'level': 'Advanced', 'year': 6},
#     {'name': 'PyTorch', 'level': 'Advanced', 'year': 5},
#     {'name': 'Keras', 'level': 'Advanced', 'year': 5},
#     {'name': 'AWS (SageMaker, S3, EC2)', 'level': 'Advanced', 'year': 5},
#     {'name': 'GCP', 'level': 'Intermediate', 'year': 3},
#     {'name': 'Spark', 'level': 'Intermediate', 'year': 4},
#     {'name': 'Hadoop', 'level': 'Intermediate', 'year': 3},
#     {'name': 'Tableau', 'level': 'Advanced', 'year': 5},
#     {'name': 'Matplotlib', 'level': 'Advanced', 'year': 6},
#     {'name': 'Seaborn', 'level': 'Advanced', 'year': 5},
#     {'name': 'Plotly', 'level': 'Advanced', 'year': 4},
#     {'name': 'PostgreSQL', 'level': 'Advanced', 'year': 5},
#     {'name': 'MongoDB', 'level': 'Intermediate', 'year': 4},
#     {'name': 'Snowflake', 'level': 'Intermediate', 'year': 3},
#     {'name': 'Git', 'level': 'Advanced', 'year': 6},
#     {'name': 'Docker', 'level': 'Advanced', 'year': 5},
#     {'name': 'Kubernetes', 'level': 'Intermediate', 'year': 3},
#     {'name': 'Airflow', 'level': 'Advanced', 'year': 4}],
#    'education': [{'degree': 'PhD in Computer Science',
#      'field': 'Machine Learning',
#      'institution': 'Stanford University',
#      'year_completed': 2018,
#      'gpa': None},
#     {'degree': 'MS in Statistics',
#      'field': 'Statistical Learning Theory',
#      'institution': 'University of California, Berkeley',
#      'year_completed': 2014,
#      'gpa': 3.92},
#     {'degree': 'BS in Mathematics',
#      'field': 'Mathematics',
#      'institution': 'Massachusetts Institute of Technology',
#      'year_completed': 2012,
#      'gpa': 3.85}],
#    'experience': [{'title': 'Senior Data Scientist',
#      'company': 'HealthMetrics Inc.',
#      'duration_years': 2.83,
#      'skills_used': ['Python',
#       'TensorFlow',
#       'AWS SageMaker',
#       'NLP',
#       'Machine Learning',
#       'Data Visualization',
#       'Team Leadership',
#       'Stakeholder Communication'],
#      'achievements': ['Led a team of 3 data scientists developing predictive models for patient readmission risk, reducing 30-day readmissions by 22%',
#       'Designed and implemented an NLP pipeline for processing clinical notes, improving diagnosis coding efficiency by 35%',
#       "Collaborated with product teams to integrate ML models into the company's healthcare analytics platform",
#       'Developed a real-time anomaly detection system for monitoring patient vitals using TensorFlow and AWS SageMaker',
#       'Presented findings and insights to C-level executives and healthcare providers'],
#      'relevance_score': 10},
#     {'title': 'Data Scientist',
#      'company': 'FinancialEdge Analytics',
#      'duration_years': 2.75,
#      'skills_used': ['Python',
#       'PyTorch',
#       'Gradient Boosting',
#       'NLP',
#       'Time Series Forecasting',
#       'Feature Engineering',
#       'ML Pipelines',
#       'Docker',
#       'Airflow'],
#      'achievements': ['Built credit risk assessment models using gradient boosting algorithms, improving default prediction accuracy by 18%',
#       'Created time series forecasting models for market trend analysis with Python and PyTorch',
#       'Engineered features from unstructured financial data using NLP techniques',
#       'Developed an automated ML pipeline for model training, validation, and deployment using Airflow and Docker',
#       'Collaborated with engineering team to implement models in production systems'],
#      'relevance_score': 9},
#     {'title': 'Data Science Intern',
#      'company': 'Novartis Pharmaceuticals',
#      'duration_years': 0.25,
#      'skills_used': ['Python',
#       'R',
#       'Statistical Modeling',
#       'Data Visualization',
#       'Clinical Data Analysis'],
#      'achievements': ['Analyzed clinical trial data to identify patterns in patient responses to experimental treatments',
#       'Assisted in developing statistical models to optimize clinical trial design',
#       'Created interactive data visualizations for research team presentations'],
#      'relevance_score': 8}]},
#   'score': {'technical_skills_score': 38,
#    'experience_score': 28,
#    'education_score': 15,
#    'additional_score': 14,
#    'total_score': 95,
#    'key_strengths': ['Exceptional proficiency in all required technical skills (Python, NumPy, Pandas, scikit-learn, SQL, machine learning algorithms, statistical modeling) at an advanced level with 5+ years of experience',
#     'Strong expertise in preferred skills including TensorFlow, PyTorch, AWS, and Tableau at advanced/intermediate levels',
#     'PhD in Computer Science (Machine Learning) from Stanford University, complemented by advanced degrees in Statistics and Mathematics',
#     'Extensive hands-on experience in healthcare and finance domains, aligning with preferred domains',
#     'Proven track record of leadership in data science teams and stakeholder communication',
#     'Demonstrated ability to deliver measurable business impact (e.g., 22% reduction in patient readmissions, 18% improvement in credit risk prediction)',
#     'Experience with modern data engineering tools (Docker, Airflow, Spark) and cloud platforms (AWS, GCP)',
#     'Strong problem-solving and communication skills as evidenced by achievements and leadership roles'],
#    'key_gaps': ['Azure expertise is missing (only GCP and AWS are covered)',
#     'Hadoop experience is intermediate (3 years) rather than advanced',
#     'No explicit mention of PowerBI (though Tableau is advanced)',
#     'Kubernetes experience is intermediate (3 years)',
#     'Snowflake experience is intermediate (3 years)'],
#    'confidence': 0.98,
#    'notes': 'Sarah Chen is an outstanding candidate who exceeds the job requirements in nearly every aspect. Her PhD in Machine Learning from Stanford, combined with 5+ years of progressive data science experience in healthcare and finance, makes her an ideal fit for roles requiring advanced technical and domain expertise. While she lacks Azure certification, her AWS and GCP expertise more than compensates. Her leadership in delivering impactful ML solutions and communication skills are particularly strong. The only minor gaps are in some niche tools (Azure, PowerBI) where her expertise in comparable tools (GCP, Tableau) likely suffices. Confidence in this evaluation is very high due to the comprehensive alignment between her profile and the job requirements.'}},
#  {'file_name': 'Resume 14_ Masaidou Ba.pdf',
#   'contact_details': {'name': 'Mamadou Saidou Balde',
#    'email': 'baldeba772@gmail.com',
#    'phone': '+33753266807',
#    'location': 'Paris, Île-de-France, France',
#    'linkedin': 'https://www.linkedin.com/in/mamadou-saidou-balde',
#    'website': 'https://github.com/mamadou-saidou-balde'},
#   'candidate_profile': {'contact_details': {'name': 'Mamadou Saidou Balde',
#     'email': 'baldeba772@gmail.com',
#     'phone': '+33753266807',
#     'location': 'Paris, Île-de-France, France',
#     'linkedin': 'https://www.linkedin.com/in/mamadou-saidou-balde',
#     'website': 'https://github.com/mamadou-saidou-balde'},
#    'skills': [{'name': 'Python', 'level': 'advanced', 'year': 5},
#     {'name': 'C', 'level': 'intermediate', 'year': 3},
#     {'name': 'SQL', 'level': 'advanced', 'year': 5},
#     {'name': 'PySpark', 'level': 'advanced', 'year': 4},
#     {'name': 'Scala', 'level': 'intermediate', 'year': 3},
#     {'name': 'R', 'level': 'intermediate', 'year': 3},
#     {'name': 'SAS', 'level': 'beginner', 'year': 1},
#     {'name': 'Scikit-learn', 'level': 'advanced', 'year': 5},
#     {'name': 'TensorFlow', 'level': 'advanced', 'year': 4},
#     {'name': 'PyTorch', 'level': 'advanced', 'year': 4},
#     {'name': 'Transformers (BERT, GPT, Mistral)',
#      'level': 'advanced',
#      'year': 4},
#     {'name': 'RAG (Retrieval-Augmented Generation)',
#      'level': 'advanced',
#      'year': 3},
#     {'name': 'LangChain / orchestration LLM', 'level': 'advanced', 'year': 3},
#     {'name': 'NLP', 'level': 'advanced', 'year': 5},
#     {'name': 'LLM', 'level': 'advanced', 'year': 4},
#     {'name': 'Computer Vision', 'level': 'intermediate', 'year': 2},
#     {'name': 'Classification', 'level': 'advanced', 'year': 4},
#     {'name': 'Embedding & Vector Store', 'level': 'advanced', 'year': 3},
#     {'name': 'Generative AI', 'level': 'advanced', 'year': 3},
#     {'name': 'Fine-tuning', 'level': 'advanced', 'year': 3},
#     {'name': 'Prompt Engineering', 'level': 'advanced', 'year': 3},
#     {'name': 'Power BI', 'level': 'advanced', 'year': 4},
#     {'name': 'Tableau', 'level': 'intermediate', 'year': 2},
#     {'name': 'Looker Studio', 'level': 'intermediate', 'year': 2},
#     {'name': 'Excel/VBA', 'level': 'advanced', 'year': 4},
#     {'name': 'PostgreSQL', 'level': 'advanced', 'year': 4},
#     {'name': 'MySQL', 'level': 'advanced', 'year': 4},
#     {'name': 'MongoDB', 'level': 'intermediate', 'year': 2},
#     {'name': 'Neo4j', 'level': 'intermediate', 'year': 2},
#     {'name': 'Microsoft SQL Server (SSAS, SSIS, SSRS)',
#      'level': 'intermediate',
#      'year': 2},
#     {'name': 'Apache Spark', 'level': 'advanced', 'year': 4},
#     {'name': 'Hadoop', 'level': 'intermediate', 'year': 2},
#     {'name': 'HDFS', 'level': 'intermediate', 'year': 2},
#     {'name': 'Databricks', 'level': 'advanced', 'year': 3},
#     {'name': 'AWS (SageMaker, EC2, S3, Lambda, ECS)',
#      'level': 'advanced',
#      'year': 3},
#     {'name': 'Microsoft Azure (Azure ML, Data Factory)',
#      'level': 'intermediate',
#      'year': 2},
#     {'name': 'Google Cloud Platform (GCP) (BigQuery, Vertex AI, Looker Studio)',
#      'level': 'intermediate',
#      'year': 2},
#     {'name': 'Docker', 'level': 'advanced', 'year': 4},
#     {'name': 'Kubernetes', 'level': 'intermediate', 'year': 2},
#     {'name': 'Jenkins', 'level': 'intermediate', 'year': 2},
#     {'name': 'Git/GitHub', 'level': 'advanced', 'year': 5},
#     {'name': 'Gerrit', 'level': 'intermediate', 'year': 2},
#     {'name': 'CI/CD', 'level': 'advanced', 'year': 4},
#     {'name': 'MLFlow', 'level': 'intermediate', 'year': 2},
#     {'name': 'Agile (Scrum)', 'level': 'advanced', 'year': 5},
#     {'name': 'Jira', 'level': 'advanced', 'year': 4},
#     {'name': 'Confluence', 'level': 'advanced', 'year': 4}],
#    'education': [{'degree': 'Master',
#      'field': 'Data Science & AI',
#      'institution': 'Data ScienceTech Institute',
#      'year_completed': 2023,
#      'gpa': None},
#     {'degree': 'Master',
#      'field': 'Mathématiques Appliquées & Statistiques',
#      'institution': 'Université Clermont Auvergne',
#      'year_completed': 2021,
#      'gpa': None},
#     {'degree': 'Licence',
#      'field': 'Mathématique',
#      'institution': 'Aix-Marseille-Université',
#      'year_completed': 2019,
#      'gpa': None}],
#    'experience': [{'title': 'AI Engineer | Data Scientist',
#      'company': 'Nokia Corporation',
#      'duration_years': 3.58,
#      'skills_used': ['Python',
#       'SQL',
#       'PySpark',
#       'Scala',
#       'Scikit-learn',
#       'TensorFlow',
#       'Power BI',
#       'PostgreSQL',
#       'Apache Spark',
#       'Docker',
#       'CI/CD',
#       'Agile (Scrum)',
#       'Jira',
#       'Confluence'],
#      'achievements': ['Extraction et traitement de très grands volumes de données complexes pour surveiller et améliorer la stabilité des builds logiciels.',
#       'Développement de métriques personnalisées pour évaluer les performances des systèmes (temps de compilation, taux de succès, stabilité des pipelines).',
#       'Développement de modèles ML (régression, classification) pour prédire les échecs de builds, réduire les erreurs et anticiper les pannes.',
#       'Conception de dashboards interactifs avec Power BI pour le suivi des indicateurs clés (temps de build, taux de succès).',
#       "Mise en place de pipelines robustes pour automatiser l'extraction, la transformation et la charge (ETL) des données en temps réel avec Python, SQL et Spark.",
#       "Chef de projet pour la conception et le déploiement d'un système automatisé de suivi de l'évolution des lignes de code (ajouts, suppressions, modifications)."],
#      'relevance_score': 10},
#     {'title': 'Data Scientist | Analyste',
#      'company': 'Michelin',
#      'duration_years': 0.17,
#      'skills_used': ['Python',
#       'SQL',
#       'Scikit-learn',
#       'TensorFlow',
#       'Feature Engineering',
#       'Machine Learning',
#       'Data Visualization'],
#      'achievements': ["Analyse d'un jeu de données de 2,7M d'observations (28 variables, 40 véhicules) issues de capteurs (accélérations 3 axes, vitesse, contexte météo, type de route, horaires).",
#       'Feature engineering pour extraire des indicateurs comportementaux (agressivité, stabilité, variations longitudinales/latérales).',
#       'Développement de modèles de ML pour optimiser la reconnaissance véhiculaire.',
#       'Identification de patterns comportementaux liés à la météo et aux horaires de trajets.'],
#      'relevance_score': 8},
#     {'title': 'Data Scientist | Analyste',
#      'company': 'Laboratoire Mathématiques de Blaise Pascal',
#      'duration_years': 0.33,
#      'skills_used': ['R',
#       'Statistical Modeling',
#       'Data Analysis',
#       'Data Visualization',
#       'SQL'],
#      'achievements': ['Analyse exploratoire et modélisation statistique sur 96 départements français (corrélations, clustering, analyse multivariée).',
#       'Étude des taux de crimes contre les personnes, cambriolages et vols automobiles en lien avec des variables socio-économiques (chômage, pauvreté, urbanisation, familles monoparentales).',
#       'Étude de corrélations significatives entre criminalité, précarité et densité urbaine.',
#       "Production d'analyses et visualisations destinées aux chercheurs du laboratoire et aux autorités partenaires."],
#      'relevance_score': 7}]},
#   'score': {'technical_skills_score': 38,
#    'experience_score': 28,
#    'education_score': 14,
#    'additional_score': 14,
#    'total_score': 94,
#    'key_strengths': ['Exceptional proficiency in core required skills (Python, SQL, scikit-learn) with 5+ years of advanced experience',
# ...
#     'Proficiency in industry-specific tools like Microsoft Project, Procore, and Bluebeam Revu'],
#    'key_gaps': ['No demonstrated experience or skills in Python, NumPy, Pandas, scikit-learn, SQL, machine learning algorithms, or statistical modeling techniques (all required technical skills)',
#     'No experience with cloud platforms (AWS, Azure, GCP) or big data tools (Spark, Hadoop) (preferred skills)',
#     'Lacks data science or AI-related education/training (degree is in Construction Management, not a quantitative field)',
#     'No exposure to data visualization tools (Tableau, PowerBI) or version control (Git) (preferred skills)',
#     'Domain experience is entirely in construction, with no background in healthcare, finance, or AI-powered analytics'],
#    'confidence': 0.95,
#    'notes': "The candidate's profile is a strong match for construction project management roles but is entirely misaligned with the data science/machine learning-focused job requirements. The candidate's skills, experience, and education are highly specialized in construction management, with no overlap in the technical or analytical domains specified. The confidence in this assessment is high due to the stark contrast between the candidate's background and the job requirements. If the role were for a construction project manager, the candidate would score very highly; however, for this data science position, they are not a viable match."}},
#  {'file_name': 'Resume 11_ Alex Patel.pdf',
#   'contact_details': {'name': 'Alex Patel',
#    'email': 'alex.patel@email.com',
#    'phone': '+1 (415) 555-4321',
#    'location': 'San Francisco, CA',
#    'linkedin': 'https://linkedin.com/in/alexpatel',
#    'website': None},
#   'candidate_profile': {'contact_details': {'name': 'Alex Patel',
#     'email': 'alex.patel@email.com',
#     'phone': '+1 (415) 555-4321',
#     'location': 'San Francisco, CA',
#     'linkedin': 'https://linkedin.com/in/alexpatel',
#     'website': None},
#    'skills': [{'name': 'Brand Strategy', 'level': 'advanced', 'year': 6},
#     {'name': 'Content Marketing', 'level': 'advanced', 'year': 6},
#     {'name': 'SEO/SEM', 'level': 'advanced', 'year': 6},
#     {'name': 'Email Marketing', 'level': 'advanced', 'year': 6},
#     {'name': 'Social Media', 'level': 'advanced', 'year': 6},
#     {'name': 'Google Analytics', 'level': 'advanced', 'year': 6},
#     {'name': 'Marketing Attribution', 'level': 'advanced', 'year': 6},
#     {'name': 'A/B Testing', 'level': 'advanced', 'year': 6},
#     {'name': 'Campaign Performance', 'level': 'advanced', 'year': 6},
#     {'name': 'HubSpot', 'level': 'advanced', 'year': 5},
#     {'name': 'Marketo', 'level': 'advanced', 'year': 5},
#     {'name': 'Salesforce', 'level': 'intermediate', 'year': 4},
#     {'name': 'Hootsuite', 'level': 'intermediate', 'year': 4},
#     {'name': 'Mailchimp', 'level': 'intermediate', 'year': 4},
#     {'name': 'Adobe Creative Suite', 'level': 'intermediate', 'year': 4},
#     {'name': 'Campaign Planning', 'level': 'advanced', 'year': 6},
#     {'name': 'Budget Management', 'level': 'advanced', 'year': 6},
#     {'name': 'Cross-functional Collaboration', 'level': 'advanced', 'year': 6},
#     {'name': 'Basic HTML/CSS', 'level': 'beginner', 'year': 2},
#     {'name': 'WordPress', 'level': 'intermediate', 'year': 3},
#     {'name': 'Shopify', 'level': 'intermediate', 'year': 3},
#     {'name': 'Microsoft Office Suite', 'level': 'advanced', 'year': 6},
#     {'name': 'English', 'level': 'native', 'year': None},
#     {'name': 'Hindi', 'level': 'fluent', 'year': None},
#     {'name': 'Spanish', 'level': 'conversational', 'year': None}],
#    'education': [{'degree': 'MBA',
#      'field': 'Marketing',
#      'institution': 'University of California, Berkeley - Haas School of Business',
#      'year_completed': 2017,
#      'gpa': 3.8},
#     {'degree': 'BA',
#      'field': 'Communications',
#      'institution': 'University of California, Los Angeles',
#      'year_completed': 2015,
#      'gpa': 3.7}],
#    'experience': [{'title': 'Senior Marketing Manager',
#      'company': 'CloudTech Solutions',
#      'duration_years': 2.83,
#      'skills_used': ['Brand Strategy',
#       'Content Marketing',
#       'SEO/SEM',
#       'Email Marketing',
#       'Social Media',
#       'Google Analytics',
#       'Marketing Attribution',
#       'A/B Testing',
#       'Campaign Performance',
#       'HubSpot',
#       'Marketo',
#       'Salesforce',
#       'Budget Management',
#       'Cross-functional Collaboration'],
#      'achievements': ['Led integrated marketing campaigns for SaaS products, resulting in 45% increase in qualified leads',
#       'Developed and implemented content marketing strategy, growing organic traffic by 65% year-over-year',
#       'Managed digital marketing budget of $1.2M with consistent positive ROI across channels',
#       'Oversaw email marketing program with 250,000+ subscribers, achieving 25% open rate and 3.5% CTR',
#       'Collaborated with product, sales, and design teams to create compelling messaging and marketing materials',
#       'Supervised team of 3 marketing specialists and coordinated with external agencies'],
#      'relevance_score': 10},
#     {'title': 'Marketing Specialist',
#      'company': 'TechStart Innovation',
#      'duration_years': 2.17,
#      'skills_used': ['Brand Strategy',
#       'Content Marketing',
#       'SEO/SEM',
#       'Email Marketing',
#       'Social Media',
#       'Google Analytics',
#       'Marketo',
#       'Campaign Performance',
#       'Cross-functional Collaboration'],
#      'achievements': ['Executed multi-channel marketing campaigns for B2B technology products',
#       'Created and optimized content for website, blog, and social media platforms',
#       'Implemented SEO strategy that increased organic search visibility by 40%',
#       'Managed marketing automation workflows in Marketo, improving lead nurturing efficiency',
#       'Analyzed campaign performance metrics and prepared reports for leadership team',
#       'Collaborated on product launches and coordinated event marketing activities'],
#      'relevance_score': 9},
#     {'title': 'Marketing Coordinator',
#      'company': 'Digital Media Agency',
#      'duration_years': 1.5,
#      'skills_used': ['Brand Strategy',
#       'Content Marketing',
#       'Social Media',
#       'Google Analytics',
#       'Campaign Planning',
#       'Cross-functional Collaboration'],
#      'achievements': ['Assisted in the planning and execution of marketing campaigns for technology clients',
#       'Created social media content and managed posting schedules across platforms',
#       'Prepared marketing performance reports using Google Analytics and social media insights',
#       'Supported event marketing activities including trade shows and webinars',
#       'Maintained marketing calendar and coordinated approval processes'],
#      'relevance_score': 8}]},
#   'score': {'technical_skills_score': 0,
#    'experience_score': 2,
#    'education_score': 5,
#    'additional_score': 0,
#    'total_score': 7,
#    'key_strengths': ['Strong marketing and brand strategy expertise with 6+ years of experience',
#     'Proven track record in content marketing, SEO/SEM, and campaign performance optimization',
#     'Advanced proficiency in marketing tools (HubSpot, Marketo, Google Analytics, Salesforce)',
#     'MBA from a top-tier institution (UC Berkeley Haas) with strong academic performance',
#     'Cross-functional collaboration and budget management experience'],
#    'key_gaps': ['No experience or skills in Python, NumPy, Pandas, scikit-learn, or other technical/data science tools required for the role',
#     'No background in machine learning algorithms, statistical modeling, or SQL',
#     'No experience with cloud platforms (AWS, Azure, GCP) or big data tools (Spark, Hadoop)',
#     'No relevant domain experience in Healthcare, Finance, or AI-powered analytics',
#     'Lacks required advanced technical skills for a data science/machine learning role'],
#    'confidence': 0.98,
#    'notes': "The candidate's profile is a strong match for marketing roles but completely misaligned with the technical requirements of this job. The candidate has extensive experience in marketing strategy, campaign execution, and marketing analytics tools, but none of the required technical skills (Python, machine learning, statistical modeling, etc.) are present. The education is relevant to marketing but does not meet the quantitative/technical requirements specified. The candidate would need significant upskilling or a different role entirely to be considered for this position."}},
#  {'file_name': 'Resume 12_ Taylor Williams.pdf',
#   'contact_details': {'name': 'Taylor Williams',
#    'email': 'hello@taylorwilliams.design',
#    'phone': '+16285557890',
#    'location': 'San Francisco, CA',
#    'linkedin': None,
#    'website': 'taylorwilliams.design'},
#   'candidate_profile': {'contact_details': {'name': 'Taylor Williams',
#     'email': 'hello@taylorwilliams.design',
#     'phone': '+16285557890',
#     'location': 'San Francisco, CA',
#     'linkedin': None,
#     'website': 'taylorwilliams.design'},
#    'skills': [{'name': 'User Interface Design',
#      'level': 'advanced',
#      'year': 5},
#     {'name': 'Interaction Design', 'level': 'advanced', 'year': 5},
#     {'name': 'Wireframing', 'level': 'advanced', 'year': 5},
#     {'name': 'Prototyping', 'level': 'advanced', 'year': 5},
#     {'name': 'Visual Design', 'level': 'advanced', 'year': 5},
#     {'name': 'Design Systems', 'level': 'advanced', 'year': 5},
#     {'name': 'User Research', 'level': 'advanced', 'year': 5},
#     {'name': 'Usability Testing', 'level': 'advanced', 'year': 5},
#     {'name': 'A/B Testing', 'level': 'intermediate', 'year': 4},
#     {'name': 'Persona Development', 'level': 'intermediate', 'year': 4},
#     {'name': 'Journey Mapping', 'level': 'intermediate', 'year': 4},
#     {'name': 'Figma', 'level': 'advanced', 'year': 5},
#     {'name': 'Adobe XD', 'level': 'advanced', 'year': 5},
#     {'name': 'Sketch', 'level': 'advanced', 'year': 5},
#     {'name': 'InVision', 'level': 'intermediate', 'year': 4},
#     {'name': 'Illustrator', 'level': 'advanced', 'year': 5},
#     {'name': 'Photoshop', 'level': 'advanced', 'year': 5},
#     {'name': 'Zeplin', 'level': 'intermediate', 'year': 4},
#     {'name': 'Miro', 'level': 'advanced', 'year': 5},
#     {'name': 'HTML/CSS', 'level': 'intermediate', 'year': 3},
#     {'name': 'JavaScript', 'level': 'basic', 'year': 2},
#     {'name': 'React', 'level': 'basic', 'year': 2},
#     {'name': 'Design Thinking', 'level': 'advanced', 'year': 5},
#     {'name': 'Agile/Scrum', 'level': 'advanced', 'year': 5},
#     {'name': 'Lean UX', 'level': 'intermediate', 'year': 4},
#     {'name': 'Design Sprints', 'level': 'intermediate', 'year': 4},
#     {'name': 'Cross-functional Teams', 'level': 'advanced', 'year': 5},
#     {'name': 'Developer Handoff', 'level': 'advanced', 'year': 5},
#     {'name': 'Product Management', 'level': 'intermediate', 'year': 4}],
#    'education': [{'degree': 'BFA in Graphic Design',
#      'field': 'Graphic Design',
#      'institution': 'California College of the Arts',
#      'year_completed': 2018,
#      'gpa': 3.85}],
#    'experience': [{'title': 'Senior UX/UI Designer',
#      'company': 'FinTech Innovations',
#      'duration_years': 2.25,
#      'skills_used': ['User Interface Design',
#       'Interaction Design',
#       'User Research',
#       'Usability Testing',
#       'Design Systems',
#       'Cross-functional Teams',
#       'Developer Handoff',
#       'Product Management',
#       'Design Thinking',
#       'Agile/Scrum'],
#      'achievements': ['Led UX/UI design for consumer-facing financial management applications with 500,000+ users',
#       'Conducted user research and usability testing to identify pain points and validate design solutions',
#       'Redesigned core features resulting in 35% improvement in task completion rates and 28% increase in user satisfaction',
#       'Created and maintained comprehensive design system, improving design consistency and development efficiency',
#       'Collaborated with product managers, engineers, and stakeholders throughout product development lifecycle',
#       'Mentored junior designers and facilitated design thinking workshops for cross-functional teams'],
#      'relevance_score': 10},
#     {'title': 'UX Designer',
#      'company': 'TechSolutions Corp',
#      'duration_years': 1.83,
#      'skills_used': ['User Interface Design',
#       'Wireframing',
#       'Prototyping',
#       'Usability Testing',
#       'Developer Handoff',
#       'Agile/Scrum'],
#      'achievements': ['Designed user interfaces for enterprise SaaS products, focusing on workflow efficiency and usability',
#       'Created wireframes, user flows, and interactive prototypes for new features and product enhancements',
#       'Conducted usability testing and synthesized findings into actionable design improvements',
#       'Collaborated with developers to ensure accurate implementation of designs',
#       'Participated in agile development process, attending daily stand-ups and sprint planning'],
#      'relevance_score': 9},
#     {'title': 'UI Designer',
#      'company': 'Creative Agency Partners',
#      'duration_years': 1.67,
#      'skills_used': ['User Interface Design',
#       'Visual Design',
#       'Interaction Design',
#       'Collaboration with UX Researchers',
#       'Client Presentations'],
#      'achievements': ['Designed user interfaces for web and mobile applications across various industries',
#       'Created visual design assets including icons, illustrations, and marketing materials',
#       'Collaborated with UX researchers to implement research findings into design solutions',
#       'Presented design concepts and rationales to clients',
#       'Participated in brainstorming sessions and concept development'],
#      'relevance_score': 8}]},
#   'score': {'technical_skills_score': 0,
#    'experience_score': 2,
#    'education_score': 5,
#    'additional_score': 0,
#    'total_score': 7,
#    'key_strengths': ['Strong design and UX/UI expertise with 5+ years of experience',
#     'Proven track record in financial technology (FinTech) domain',
#     'Advanced proficiency in design tools (Figma, Adobe XD, Sketch, Illustrator, Photoshop)',
#     'Experience with cross-functional collaboration and Agile/Scrum methodologies',
#     'Strong problem-solving and communication skills (implied by role requirements)'],
#    'key_gaps': ['No demonstrated experience with Python, NumPy, Pandas, scikit-learn, or other machine learning/data science tools',
#     'No SQL or statistical modeling experience',
#     'No experience with TensorFlow, PyTorch, or cloud platforms (AWS, Azure, GCP)',
#     'Lacks required advanced technical skills for data science/machine learning roles',
#     "Education does not meet the minimum requirement (BFA in Graphic Design vs. Master's in CS/Statistics/Mathematics)",
#     'No experience with Spark, Hadoop, Tableau, PowerBI, or Git',
#     'Limited technical implementation skills (only basic HTML/CSS and JavaScript)',
#     'No direct experience with healthcare, finance analytics, or AI-powered analytics domains from a technical perspective'],
#    'confidence': 0.98,
#    'notes': "The candidate is an exceptional UX/UI designer with deep experience in financial technology applications, but their profile is entirely misaligned with the technical requirements of this role. The job clearly seeks a data scientist/machine learning engineer, while the candidate is a design professional. The only potential overlap is in the 'problem-solving' and 'communication skills' areas, which are generic and not specific to the technical stack required. The experience score is minimal because while the candidate has relevant domain experience (FinTech), they lack the technical skills to perform the core job functions. The education score is low because the degree is not in a quantitative field and does not meet the minimum requirement. Additional skills are non-existent for this role. The candidate would be better suited for UX/UI design roles, particularly in FinTech or product design, rather than data science positions."}}]
